# %%
from datasets import CasiaSurfDataset

# %%
dataset = CasiaSurfDataset(protocol=1, train=False)
# Out:
# ['../data/CASIA_SURF/dev/003000/profile/0064.jpg', '../data/CASIA_SURF/dev/003000/profile/0025.jpg', '../data/CASIA_SURF/dev/003000/profile/0070.jpg', '../data/CASIA_SURF/dev/003000/profile/0009.jpg', '../data/CASIA_SURF/dev/003000/profile/0001.jpg', '../data/CASIA_SURF/dev/003000/profile/0079.jpg', '../data/CASIA_SURF/dev/003000/profile/0003.jpg', '../data/CASIA_SURF/dev/003000/profile/0075.jpg', '../data/CASIA_SURF/dev/003000/profile/0090.jpg', '../data/CASIA_SURF/dev/003000/profile/0052.jpg', '../data/CASIA_SURF/dev/003000/profile/0047.jpg', '../data/CASIA_SURF/dev/003000/profile/0037.jpg', '../data/CASIA_SURF/dev/003000/profile/0077.jpg', '../data/CASIA_SURF/dev/003000/profile/0032.jpg', '../data/CASIA_SURF/dev/003000/profile/0080.jpg', '../data/CASIA_SURF/dev/003000/profile/0068.jpg', '../data/CASIA_SURF/dev/003000/profile/0015.jpg', '../data/CASIA_SURF/dev/003000/profile/0028.jpg', '../data/CASIA_SURF/dev/003000/profile/0024.jpg', '../data/CASIA_SURF/dev/003000/profile/0040.jpg
# ...

# %%
import re

m = re.search(r'(?P<id>dev/\d+)','../data/CASIA_SURF/dev/003067/profile/0007.jpg')
m.group('id')
# Out:
# 'dev/003067'

# %%
# !ls
# Out:
# datasets.py  __pycache__  submission.txt  submit.py  train.py  Untitled.ipynb

# %%
# !python submit.py
# Out:
# Traceback (most recent call last):
#   File "submit.py", line 46, in <module>
#     for i, batch in enumerate(dataloader):
#   File "/home/itrushkin/anaconda3/envs/antispoofing/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 346, in __next__
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/home/itrushkin/anaconda3/envs/antispoofing/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/itrushkin/anaconda3/envs/antispoofing/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/itrushkin/Documents/face-anti-spoofer/src/datasets.py", line 72, in __getitem__
#     img = Image.open(img_path)
#   File "/home/itrushkin/anaconda3/envs/antispoofing/lib/python3.7/site-packages/PIL/Image.py", line 2766, in open
# ...
